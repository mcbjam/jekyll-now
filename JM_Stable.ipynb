# %% [markdown]
# <a href="https://colab.research.google.com/github/mcbjam/AHD3/blob/master/JM_Stable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi

# %%
# !pip install diffusers==0.11.1
# !pip install transformers scipy ftfy accelerate

# %%
from datetime import datetime

# %%
from diffusers import StableDiffusionPipeline
import torch

#model_id = "Fictiverse/Stable_Diffusion_PaperCut_Model"
model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
# Out:
# ...
# Fetching 19 files:   0%|          | 0/19 [00:00<?, ?it/s]
# ...
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.

# %%
pipe = pipe.to("cuda")
output="output/"

# %%
prompt = "Keanu Reeves portrait photo of a asia old warrior chief, tribal panther make up, blue on red, side profile, looking away, serious eyes, 50mm portrait photography, hard rim lighting photography"
image = pipe(prompt, height=512, width=768).images[0]  # image here is in [PIL format](https://pillow.readthedocs.io/en/stable/)

# Now to display an image you can either save it such as:
image.save(f""+output+"/imafe"+datetime.now().strftime("%H:%M:%S")+".png")

# or if you're in a google colab you can directly display it with 
image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=768x512 at 0x7F7A02EBFD00>

# %%
output="output2/"

from PIL import Image

def image_grid(imgs, rows, cols):
    assert len(imgs) == rows*cols
    w, h = imgs[0].size
    grid = Image.new('RGB', size=(cols*w, rows*h))
    grid_w, grid_h = grid.size
    for i, img in enumerate(imgs):
        grid.paste(img, box=(i%cols*w, i//cols*h))
    return grid

num_cols = 1
num_rows = 50

prompt = ["Keanu Reeves portrait photo of a asia old warrior chief, tribal panther make up, blue on red, side profile, looking away, serious eyes, 50mm portrait photography, hard rim lighting photography"] * num_cols

all_images = []
for i in range(num_rows):
  images = pipe(prompt, height=512, width=768).images
  image=images[0]
  image.save(f""+output+"/image"+str(i)+datetime.now().strftime("%H:%M:%S")+".png")
  image
  all_images.extend(images)
  
  
 
grid = image_grid(all_images, rows=num_rows, cols=num_cols)
grid

# %%
# !zip -r output2.zip output2

# %%
blue_on_red = [
"Navy on Crimson",
    "Sapphire on Scarlet",
    "Cobalt on Burgundy",
    "Indigo on Ruby",
    "Turquoise on Cherry",
    "Teal on Vermilion",
    "Azure on Carmine",
    "Cerulean on Maroon",
    "Denim on Garnet",
    "Sky on Cardinal",
    "Powder on Brick",
    "Steel on Tomato",
    "Cornflower on Merlot",
    "Royal on Crimson",
    "Periwinkle on Ruby",
    "Iris on Burgundy",
    "Aqua on Scarlet",
    "Baby on Vermilion",
    "Navy on Cherry",
    "Slate on Maroon",
    "Cyan on Garnet",
    "Cerulean on Cardinal",
    "Turquoise on Tomato",
    "Cobalt on Merlot",
    "Sapphire on Crimson",
    "Teal on Ruby",
    "Indigo on Burgundy",
    "Denim on Scarlet",
    "Sky on Vermilion",
    "Azure on Cherry",
    "Cornflower on Maroon",
    "Powder on Garnet",
    "Steel on Cardinal",
    "Periwinkle on Tomato",
    "Iris on Merlot",
    "Royal on Crimson",
    "Aqua on Ruby",
    "Baby on Burgundy",
    "Navy on Vermilion",
    "Slate on Cherry",
    "Cyan on Maroon",
    "Cerulean on Garnet",
    "Turquoise on Cardinal",
    "Cobalt on Tomato",
    "Sapphire on Merlot",
    "Teal on Crimson",
    "Indigo on Ruby",
    "Denim on Burgundy",
    "Sky on Scarlet",
    "Azure on Vermilion",
    "Cornflower on Cherry",
    "Powder on Maroon",
    "Steel on Garnet"
]

# Afficher chaque valeur de la liste
for value in blue_on_red:
    print(value)
# Out:
# Navy on Crimson
# Sapphire on Scarlet
# Cobalt on Burgundy
# Indigo on Ruby
# Turquoise on Cherry
# Teal on Vermilion
# Azure on Carmine
# Cerulean on Maroon
# Denim on Garnet
# Sky on Cardinal
# Powder on Brick
# Steel on Tomato
# Cornflower on Merlot
# Royal on Crimson
# Periwinkle on Ruby
# Iris on Burgundy
# Aqua on Scarlet
# Baby on Vermilion
# Navy on Cherry
# Slate on Maroon
# Cyan on Garnet
# Cerulean on Cardinal
# Turquoise on Tomato
# Cobalt on Merlot
# Sapphire on Crimson
# Teal on Ruby
# Indigo on Burgundy
# Denim on Scarlet
# Sky on Vermilion
# Azure on Cherry
# Cornflower on Maroon
# Powder on Garnet
# Steel on Cardinal
# Periwinkle on Tomato
# Iris on Merlot
# Royal on Crimson
# Aqua on Ruby
# Baby on Burgundy
# Navy on Vermilion
# Slate on Cherry
# Cyan on Maroon
# Cerulean on Garnet
# Turquoise on Cardinal
# Cobalt on Tomato
# Sapphire on Merlot
# Teal on Crimson
# Indigo on Ruby
# Denim on Burgundy
# Sky on Scarlet
# Azure on Vermilion
# Cornflower on Cherry
# ...

# %%
makeup_variations = [
"Tribal panther face painting",
    "Panther-inspired tribal makeup",
    "Panther tribal face art",
    "Tribal panther face design",
    "Panther-themed tribal makeup",
    "Tribal panther face embellishment",
    "Panther tribal face adornment",
    "Panther-inspired tribal face markings",
    "Tribal panther face decoration",
    "Panther-themed tribal face painting",
    "Tribal panther face artistry",
    "Panther tribal face ornamentation",
    "Panther-inspired tribal face patterns",
    "Tribal panther face embellishments",
    "Panther tribal face adornments",
    "Tribal panther face designs",
    "Panther-themed tribal face art",
    "Tribal panther face decorations",
    "Panther-inspired tribal face makeup",
    "Panther tribal face markings",
    "Tribal panther face art",
    "Panther-themed tribal face embellishment",
    "Tribal panther face adornment",
    "Panther-inspired tribal face designs",
    "Tribal panther face decoration",
    "Panther-themed tribal face painting",
    "Tribal panther face artistry",
    "Panther tribal face ornamentation",
    "Panther-inspired tribal face patterns",
    "Tribal panther face embellishments",
    "Panther tribal face adornments",
    "Tribal panther face designs",
    "Panther-themed tribal face art",
    "Tribal panther face decorations",
    "Panther-inspired tribal face makeup",
    "Panther tribal face markings",
    "Tribal panther face art",
    "Panther-themed tribal face embellishment",
    "Tribal panther face adornment",
    "Panther-inspired tribal face designs",
    "Tribal panther face decoration",
    "Panther-themed tribal face painting",
    "Tribal panther face artistry",
    "Panther tribal face ornamentation",
    "Panther-inspired tribal face patterns",
    "Tribal panther face embellishments",
    "Panther tribal face adornments",
    "Tribal panther face designs",
    "Panther-themed tribal face art",
    "Tribal panther face decorations",
    "Panther-inspired tribal face makeup",
    "Panther tribal face markings",
    "Tribal panther face art"
    "Maquillage tribal panthère avec des détails de symboles aztèques pour une touche culturelle."
]

# Afficher chaque valeur de la liste
for value in makeup_variations:
    print(value)

# %%
serious_eyes_variations = [
   "Intense eyes",
    "Focused gaze",
    "Piercing look",
    "Stoic eyes",
    "Determined eyes",
    "Solemn expression",
    "Fixed stare",
    "Grave countenance",
    "Severe look",
    "Brooding eyes",
    "Penetrating gaze",
    "Stern eyes",
    "Thoughtful eyes",
    "Contemplative expression",
    "Earnest look",
    "Somber eyes",
    "Reflective gaze",
    "Concentrated expression",
    "Profound eyes",
    "Austere look",
    "Deep-set eyes",
    "Inquisitive gaze",
    "Restrained expression",
    "Analytical eyes",
    "Resolute look",
    "Serene eyes",
    "Engaged gaze",
    "Assured expression",
    "Composed eyes",
    "Focused look",
    "Calm eyes",
    "Attentive gaze",
    "Assured expression",
    "Serene eyes",
    "Engaged gaze",
    "Brightened expression",
    "Sparkling eyes",
    "Interested look",
    "Enthusiastic gaze",
    "Animated expression",
    "Cheerful eyes",
    "Lively look",
    "Joyful eyes",
    "Radiant gaze",
    "Smiling expression",
    "Happy eyes",
    "Playful look",
    "Blissful gaze",
    "Delighted expression",
    "Mirthful eyes",
    "Cheerful look",
    "Exuberant eyes",
    "Beaming gaze",
    "Joyful expression"
]

# Afficher chaque valeur de la liste
for value in serious_eyes_variations:
    print(value)
# Out:
# Intense eyes
# Focused gaze
# Piercing look
# Stoic eyes
# Determined eyes
# Solemn expression
# Fixed stare
# Grave countenance
# Severe look
# Brooding eyes
# Penetrating gaze
# Stern eyes
# Thoughtful eyes
# Contemplative expression
# Earnest look
# Somber eyes
# Reflective gaze
# Concentrated expression
# Profound eyes
# Austere look
# Deep-set eyes
# Inquisitive gaze
# Restrained expression
# Analytical eyes
# Resolute look
# Serene eyes
# Engaged gaze
# Assured expression
# Composed eyes
# Focused look
# Calm eyes
# Attentive gaze
# Assured expression
# Serene eyes
# Engaged gaze
# Brightened expression
# Sparkling eyes
# Interested look
# Enthusiastic gaze
# Animated expression
# Cheerful eyes
# Lively look
# Joyful eyes
# Radiant gaze
# Smiling expression
# Happy eyes
# Playful look
# Blissful gaze
# Delighted expression
# Mirthful eyes
# Cheerful look
# Exuberant eyes
# Beaming gaze
# Joyful expression

# %%
asia_warrior_variations = [
    "Aged Asian warrior chieftain",
    "Old Asian warlord",
    "Venerable chief of Asian warriors",
    "Experienced Asian warrior leader",
    "Seasoned warrior chief from Asia",
    "Ancient Asian battle commander",
    "Respected elder warrior from Asia",
    "Mature Asian tribal chief",
    "Honorable Asian war general",
    "Distinguished Asian warrior lord",
    "Eminent Asian warlord",
    "Wise old warrior chief from Asia",
    "Aged martial arts master from Asia",
    "Dignified Asian warlord",
    "Esteemed Asian chieftain",
    "Exalted Asian warrior chief",
    "Sage Asian battle veteran",
    "Experienced warlord of Asia",
    "Revered Asian war hero",
    "Aged samurai leader from Asia",
    "Highly respected Asian warrior chief",
    "Venerated Asian war chieftain",
    "Renowned Asian battle strategist",
    "Noble Asian warlord",
    "Gallant Asian tribal chief",
    "Distinguished Asian martial arts master",
    "Venerated Asian battle commander",
    "Fearless Asian warrior lord",
    "Glorious Asian war hero",
    "Elder statesman of Asian warriors",
    "Honored Asian warlord",
    "Majestic Asian warrior chief",
    "Ancient Asian war veteran",
    "Respected elder of Asian tribes",
    "Wise Asian battle leader",
    "Esteemed Asian war chieftain",
    "Experienced Asian war commander",
    "Distinguished Asian martial arts grandmaster",
    "Valiant Asian warrior chief",
    "Seasoned Asian warlord",
    "Venerated elder of Asian warriors",
    "Renowned Asian battle hero",
    "Gallant Asian tribal leader",
    "Dignified Asian war general",
    "Noble Asian warlord",
    "Exalted Asian warrior chief",
    "Honorable Asian battle veteran",
    "Esteemed leader of Asian tribes",
    "Sage Asian war chieftain",
    "Venerable Asian warlord",
    "Highly respected Asian warrior commander"
]

# Afficher chaque valeur de la liste
for value in asia_warrior_variations:
    print(value)

# %%
landscape_descriptions = [
    "Vast desert dunes under a clear blue sky",
    "Rolling green hills stretching to the horizon",
    "Majestic snow-capped mountains reflecting in a serene lake",
    "Endless fields of colorful wildflowers",
    "Towering cliffs overlooking a crashing ocean",
    "Lush tropical rainforest with a cascading waterfall",
    "Golden wheat fields swaying in the breeze",
    "Glistening icebergs floating in a pristine Arctic sea",
    "Dramatic canyons carved by ancient rivers",
    "Misty and mysterious ancient forests",
    "Expansive lavender fields in full bloom",
    "Serenely calm and mirror-like alpine lake",
    "Picturesque vineyards with rows of grapevines",
    "Awe-inspiring northern lights dancing in the night sky",
    "Sunset over a serene coastal landscape",
    "Majestic redwood trees reaching towards the sky",
    "Fiery red and orange autumn foliage",
    "Glistening snow-covered peaks in a winter wonderland",
    "Gentle rolling waves crashing on a sandy beach",
    "Vibrant and bustling city skyline at night",
    "Peaceful countryside dotted with quaint farmhouses",
    "Mysterious and mist-covered ancient ruins",
    "Spectacular fjords surrounded by towering cliffs",
    "Dazzling fields of tulips in full bloom",
    "Sparkling turquoise lakes nestled in a mountain valley",
    "Dramatic volcanic landscapes with rugged terrain",
    "Sweeping views of a vast and colorful canyon",
    "Enchanting cherry blossom trees in a serene garden",
    "Serenity of a tranquil and untouched wilderness",
    "Sunrise casting a golden glow over a tranquil meadow",
    "Breathtaking coastal cliffs with crashing waves below",
    "Spectacular natural arch formations against a deep blue sky",
    "Peaceful countryside with grazing livestock and rolling hills",
    "Lively and colorful marketplaces filled with exotic goods",
    "Picturesque lighthouse overlooking a rocky shoreline",
    "Sunflower fields stretching as far as the eye can see",
    "Dramatic ice formations in a frozen arctic landscape",
    "Lively and bustling cityscape with towering skyscrapers",
    "Rugged and untamed wilderness with untouched beauty",
    "Quaint and charming village nestled in a valley",
    "Expansive fields of blooming lavender in Provence",
    "Cascading waterfalls amidst lush green mountains",
    "Idyllic and peaceful countryside with grazing sheep",
    "Remote and untouched sandy desert stretching into the distance",
    "Peaceful and serene countryside dotted with windmills",
    "Ancient and mysterious stonehenge against a dramatic sky",
    "Majestic and towering palm trees on a tropical beach",
    "Bustling and vibrant street market in a foreign city",
    "Picturesque vineyard with rows of grapevines and a rustic farmhouse"
]

# %%
scene_descriptions = [
    "A serene beach at sunrise, with gentle waves lapping against the shore and seagulls flying overhead.",
    "A bustling city street filled with people, colorful signs, and the sounds of car horns and chatter.",
    "A peaceful countryside landscape, with rolling green hills, grazing sheep, and a charming farmhouse in the distance.",
    "A majestic mountain range, with snow-capped peaks, winding hiking trails, and a crystal-clear mountain lake at the base.",
    "A vibrant and bustling market, with vendors selling fresh fruits, colorful spices, and handmade crafts.",
    "A tranquil garden filled with blooming flowers, chirping birds, and a peaceful koi pond.",
    "A cozy and inviting cafe, with the aroma of freshly brewed coffee, soft jazz music playing in the background, and people engaged in conversation.",
    "A dense and enchanting forest, with towering trees, rays of sunlight peeking through the canopy, and the sounds of chirping birds and rustling leaves.",
    "A breathtaking waterfall, cascading down a rocky cliff into a pool of crystal-clear water, surrounded by lush green vegetation.",
    "A lively and energetic concert, with a stage lit up by colorful lights, the beat of music pulsating through the air, and a crowd of enthusiastic fans.",
    "A picturesque vineyard, with rows of grapevines, a rustic winery building, and a breathtaking view of the rolling hills in the background.",
    "A futuristic cityscape, with towering skyscrapers, sleek flying cars zooming through the air, and holographic billboards illuminating the streets.",
    "A peaceful and serene lake, with ducks swimming lazily, a gentle breeze rustling the surrounding trees, and a beautiful sunset painting the sky in vibrant hues.",
    "A bustling and vibrant street market in a foreign country, with vendors shouting their prices, colorful stalls filled with exotic fruits and spices, and the aroma of street food filling the air.",
    "A charming and picturesque village, with cobblestone streets, quaint cottages with flower-filled window boxes, and a village square bustling with locals.",
    "A dramatic and awe-inspiring canyon, with towering rock formations, narrow winding paths, and a river carving its way through the rugged landscape.",
    "A tranquil and secluded beach, with powdery white sand, clear turquoise waters, and palm trees swaying in the gentle ocean breeze.",
    "A mystical and otherworldly night sky, with a blanket of stars stretching as far as the eye can see, and a faint glow of the Milky Way.",
    "A vibrant and colorful carnival, with lively music, swirling carousel lights, and people enjoying thrilling rides and indulging in sugary treats.",
    "A cozy and inviting winter cabin, with a crackling fireplace, snow falling gently outside, and a warm cup of hot chocolate in hand.",
    "A vast and arid desert, with rolling sand dunes stretching for miles, a scorching sun overhead, and the occasional oasis providing a glimmer of hope.",
    "A romantic and enchanting Venetian canal, with gondolas gliding along the shimmering water, ancient buildings reflecting in the canal, and the distant sound of singing gondoliers.",
    "A serene and peaceful mountain meadow, with colorful wildflowers, grazing deer, and a breathtaking view of the surrounding peaks.",
    "A mystical and ancient temple, with intricate carvings, fragrant incense filling the air, and the sound of monks chanting in prayer.",
    "A vast and expansive savannah, with herds of grazing animals, the distant roar of lions, and a breathtaking sunset painting the sky in shades of orange and purple.",
"A charming and quaint seaside village, with colorful fishing boats, charming cottages, and seagulls soaring overhead.",
"A tranquil and secluded waterfall hidden deep in the forest, with moss-covered rocks, ferns lining the edges, and the sound of rushing water creating a soothing ambiance.",
"A lively and bustling street in a vibrant Chinatown, with ornate red lanterns hanging overhead, delicious aromas wafting from street food stalls, and a vibrant display of cultural traditions.",
"A breathtaking alpine landscape, with snow-capped mountains, frozen lakes, and a clear blue sky that reflects in the mirror-like surface of the water.",
"A surreal and dreamlike field of lavender, with rows of vibrant purple flowers stretching as far as the eye can see, and the scent of lavender filling the air.",
"A quaint and charming English countryside, with rolling green hills, grazing sheep, and picturesque cottages covered in ivy.",
"A vibrant and bustling street in a Moroccan souk, with vibrant textiles hanging overhead, the aroma of spices in the air, and the sounds of merchants bargaining with customers.",
"A mystical and enchanting forest at dusk, with rays of golden sunlight piercing through the canopy, creating an ethereal atmosphere.",
"A serene and idyllic tropical island, with palm-fringed beaches, turquoise waters teeming with colorful marine life, and a gentle sea breeze.",
"A lively and energetic street festival, with colorful decorations, street performers, and people dancing to lively music.",
"A remote and untouched wilderness, with towering mountains, pristine lakes, and the call of wild animals echoing in the distance.",
"A charming and picturesque vineyard in the countryside, with neat rows of grapevines, a rustic tasting room, and a breathtaking view of the surrounding vineyards.",
"A peaceful and tranquil Japanese garden, with meticulously manicured bonsai trees, a serene koi pond, and a traditional wooden bridge.",
"A magnificent and imposing castle, with grand turrets, a moat, and lush gardens that surround the historic structure.",
"A vibrant and bustling night market, with rows of colorful stalls selling street food, souvenirs, and lively entertainment.",
"A serene and picturesque waterfall nestled in a lush rainforest, with cascading water, vibrant flora, and the sounds of chirping birds.",
"A dramatic and breathtaking coastal cliff, with waves crashing against the rocks below, and a panoramic view of the vast ocean stretching into the horizon.",
"A charming and cozy log cabin nestled in a snowy forest, with smoke curling from the chimney, and the sound of crackling firewood.",
"A magical and enchanting winter wonderland, with snow-covered trees, twinkling lights, and a sense of warmth and joy in the air.",
"A tranquil and serene Zen garden, with meticulously raked gravel, strategically placed rocks, and a meditative ambiance.",
"A bustling and vibrant floating market, with colorful boats selling fresh fruits, vegetables, and local handicrafts.",
"A vast and expansive field of sunflowers, with their vibrant yellow petals facing the sun, creating a sea of golden beauty.",
"A breathtaking and majestic waterfall surrounded by lush greenery, with misty spray that creates a rainbow in the sunlight.",
"A charming and picturesque cobblestone street in a historic European town, with colorful facades, charming cafes, and the sound of footsteps echoing through the narrow alleyways.",
"A peaceful and serene oasis in the middle of the desert, with palm trees swaying in the breeze, a tranquil pool of water, and a sense of respite from the harsh surroundings.",
"A tranquiland enchanting cherry blossom garden in full bloom, with delicate pink petals floating in the air and creating a magical atmosphere.",
"A breathtaking and rugged coastal cliff, with crashing waves below and a panoramic view of the endless ocean.",
"A picturesque and charming countryside cottage, with a thatched roof, blooming flower gardens, and a cozy fireplace inside.",
"A vibrant and bustling street market in an exotic bazaar, with vibrant textiles, intricate handicrafts, and the aroma of exotic spices.",
"A tranquil and secluded alpine lake, with crystal-clear turquoise waters, surrounded by majestic mountains and lush pine forests.",
"A mystical and enchanting forest covered in a blanket of fog, with towering trees shrouded in mystery and an ethereal ambiance.",
"A stunning and serene sunset over a calm lake, with vibrant hues of orange, pink, and purple reflecting on the water's surface.",
"A lively and energetic street filled with street performers, musicians, and artists showcasing their talents to captivated crowds.",
"A remote and untouched paradise beach, with powdery white sand, swaying palm trees, and clear azure waters that invite relaxation and serenity.",
"A picturesque and charming countryside vineyard, with rows of grapevines, a rustic tasting room, and breathtaking views of rolling hills and valleys.",
"A majestic and imposing castle perched on a hilltop, with intricate architecture, a drawbridge, and a commanding view of the surrounding landscape.",
"A tranquil and serene Japanese tea garden, with meticulously manicured bonsai trees, stone pathways, and a traditional tea house.",
"A bustling and colorful flower market, with rows of vibrant blooms, fragrant scents filling the air, and vendors arranging bouquets with care.",
"A peaceful and idyllic riverside scene, with a gentle stream flowing through lush greenery, and birds singing harmoniously in the trees.",
"A magical and enchanting forest illuminated by fireflies, with their soft glow creating a whimsical and ethereal atmosphere.",
"A lively and vibrant carnival, with colorful rides, bright lights, and the sound of laughter and excitement in the air.",
"A tranquil and secluded cabin by a serene mountain lake, with a crackling fire, a cozy reading nook, and a breathtaking view of nature's beauty.",
"A captivating and awe-inspiring sunrise over a mist-covered valley, with rays of golden light piercing through the clouds and casting a warm glow.",
"A bustling and vibrant Chinatown, with traditional architecture, street food vendors, and a lively atmosphere filled with cultural traditions.",
"A peaceful and picturesque countryside farm, with rolling fields, grazing animals, and a charming farmhouse nestled among the greenery.",
"A breathtaking and expansive canyon, with towering rock formations, deep ravines, and a sense of grandeur that takes your breath away.",
"A serene and tranquil forest glade, with sunlight filtering through the canopy, a gentle babbling brook, and a peaceful sense of harmony.",
"A lively and bustling night market, with rows of food stalls selling delicious treats, lively entertainment, and a vibrant atmosphere.",
"A stunning and dramatic coastal sunset, with vivid hues of pink, orange, and gold painting the sky and reflecting on the shimmering water.",
"A quaint and charming European village, with cobblestone streets, colorful houses, and a cozy village square bustling with locals.",
"A serene and picturesque rice terrace, with lush green fields cascading down the hillsides, creating a breathtaking agricultural landscape.",
"A bustling and energetic city skyline, with towering skyscrapers, vibrant neon lights, and a sense of constant motion and excitement.",
"A secluded and hidden waterfall in the heartof a lush rainforest, with moss-covered rocks, ferns, and tropical birds fluttering around, creating a tranquil oasis of natural beauty.",
"A breathtaking and expansive lavender field, with rows upon rows of fragrant purple flowers stretching as far as the eye can see, creating a colorful and aromatic landscape.",
"A tranquil and serene desert oasis, with palm trees swaying in the breeze, a shimmering pool of water, and a sense of calm and tranquility amidst the arid surroundings.",
"A vibrant and bustling street in a Moroccan medina, with narrow alleyways, vibrant market stalls, and the scent of spices lingering in the air.",
"A picturesque and charming coastal village, with colorful fishing boats bobbing in the harbor, quaint seaside cafes, and a panoramic view of the sparkling sea.",
"A peaceful and idyllic countryside meadow, with wildflowers blooming in vibrant colors, butterflies fluttering around, and the sound of buzzing bees in the air.",
"A majestic and awe-inspiring glacier, with towering ice formations, sparkling blue hues, and a sense of grandeur and wonder.",
"A lively and energetic street in a bustling Asian night market, with a plethora of street food stalls, vibrant decorations, and a constant buzz of activity.",
"A tranquil and serene Zen rock garden, with carefully arranged stones, raked gravel patterns, and a sense of tranquility and contemplation.",
"A charming and historic European castle nestled amidst rolling hills, with turrets, a drawbridge, and a lush surrounding moat.",
"A breathtaking and expansive sunflower field, with golden flowers reaching towards the sun, creating a sea of vibrant yellow that stretches to the horizon.",
"A serene and picturesque alpine village, with charming chalets, snow-covered rooftops, and a backdrop of majestic snow-capped mountains.",
"A lively and vibrant street in an Indian market, with colorful textiles, intricate handicrafts, and the aroma of spices filling the air.",
"A tranquil and peaceful lakeside retreat, with a wooden dock stretching into the calm waters, surrounded by lush greenery and the sound of chirping birds.",
"A mystical and enchanting forest shrouded in mist, with towering trees, ethereal light filtering through the fog, and a sense of mystery and intrigue.",
"A bustling and lively farmers market, with stalls filled with fresh produce, artisanal goods, and the chatter of vendors and shoppers.",
"A breathtaking and dramatic cliffside view, with waves crashing against the rocks below, and a panoramic vista of the endless ocean stretching into the distance.",
"A cozy and inviting cabin nestled in a snowy mountain landscape, with a roaring fireplace, warm blankets, and a view of snow-covered peaks.",
"A magical and enchanting winter forest, with snow-laden trees, a carpet of white covering the ground, and the sound of silence that accompanies a winter wonderland.",
"A tranquil and serene Japanese garden in autumn, with vibrant red and orange maple trees, a peaceful koi pond, and the gentle sound of falling leaves.",
"A bustling and vibrant night market in a bustling Asian city, with illuminated stalls, street performers, and a lively atmosphere filled with delicious aromas.",
"A picturesque and charming vineyard at sunset, with rows of grapevines bathed in golden light, a rustic wine cellar, and a sense of tranquility and serenity.",
"A stunning and majestic waterfall surrounded by lush tropical foliage, with cascading water creating a soothing and mesmerizing spectacle.",
"A charming and cozy European village square, with a central fountain, outdoor cafes, and the sound of laughter and conversation filling the air.",
"A peaceful and serene countryside landscape atdawn, with gentle mist hovering over rolling green hills, grazing livestock, and the soft rays of the rising sun casting a warm glow.",
"A lively and bustling street in a vibrant South American market, with colorful textiles, traditional music, and a feast of flavors from street food vendors.",
"A tranquil and secluded beach cove, with powdery white sand, clear turquoise waters, and towering cliffs offering a sense of seclusion and natural beauty.",
"A breathtaking and expansive vineyard at harvest time, with workers picking grapes, the sweet aroma of ripe fruit in the air, and the anticipation of a fruitful harvest.",
"A cozy and intimate jazz club, with dim lighting, soulful music filling the room, and the clinking of glasses as patrons immerse themselves in the captivating melodies.",
"A serene and picturesque countryside covered in a blanket of fresh snow, with snow-capped trees, glistening fields, and the silence that comes with a winter wonderland.",
"A bustling and vibrant floating market in Southeast Asia, with vendors in traditional boats selling fresh produce, colorful textiles, and local handicrafts.",
"A tranquil and serene hilltop overlooking a valley, with wildflowers swaying in the gentle breeze, a breathtaking view, and a sense of peace and serenity.",
"A charming and historic European city square, with cobblestone streets, ornate architecture, outdoor cafes, and the joyful hum of conversation.",
"A mesmerizing and colorful coral reef, with an abundance of marine life, vibrant corals, and crystal-clear waters inviting exploration and awe.",
"A lively and bustling street in a bustling African market, with vibrant fabrics, exotic spices, and the rhythmic beats of drums in the distance.",
"A peaceful and picturesque countryside covered in blooming cherry blossom trees, with delicate petals floating in the air, creating a scene of natural beauty.",
"A majestic and awe-inspiring volcano, with billowing smoke, fiery lava flows, and a sense of both danger and awe in the face of nature's power.",
"A vibrant and lively street in a Caribbean town, with colorful buildings, reggae music playing in the background, and the scent of tropical fruits in the air.",
"A tranquil and serene lakeside retreat surrounded by towering pine trees, with a wooden dock, a rowboat gently rocking in the water, and the sound of birdsong.",
"A mystical and enchanting forest glen, with moss-covered stones, a babbling brook, and sunlight filtering through the canopy, creating a magical atmosphere.",
"A bustling and vibrant street in a Middle Eastern souk, with aromatic spices, intricate carpets, and the melodious sound of merchants haggling.",
"A serene and picturesque countryside covered in blooming sunflowers, with their vibrant yellow faces following the sun, creating a field of natural beauty.",
"A lively and energetic street in a bustling Asian metropolis, with towering skyscrapers, neon lights, and a constant flow of people and traffic.",
"A tranquil and peaceful coastal inlet, with calm waters, a sandy beach, and seagulls gliding gracefully overhead, offering a sense of serenity and escape.",
"A charming and cozy mountain chalet, nestled amidst a pine forest, with a crackling fireplace, warm blankets, and breathtaking views of snow-capped peaks.",
"A magical and enchanting autumn forest, with trees ablaze in shades of red, orange, and gold, creating a vibrant tapestry of colors.",
"A bustling and vibrant street in a lively Latin American market, with lively music, street performers, and a colorful array of fresh fruits and vegetables.",
]

i=1
# Afficher chaque valeur de la liste
for value in scene_descriptions:
  print(i)
  i=i+1
  print(value)

# %%
endroits_populaires = [
    "Paris, France",
    "New York City, États-Unis",
    "Rome, Italie",
    "Barcelone, Espagne",
    "Tokyo, Japon",
    "Londres, Royaume-Uni",
    "Rio de Janeiro, Brésil",
    "Le Caire, Égypte",
    "Sydney, Australie",
    "Amsterdam, Pays-Bas",
    "Istanbul, Turquie",
    "Dubai, Émirats arabes unis",
    "Bali, Indonésie",
    "Santorin, Grèce",
    "Cancún, Mexique",
    "Le Cap, Afrique du Sud",
    "Bora Bora, Polynésie française",
    "Machu Picchu, Pérou",
    "Venise, Italie",
    "Hong Kong, Chine",
    "Moscou, Russie",
    "Los Angeles, États-Unis",
    "Berlin, Allemagne",
    "Le Caire, Égypte",
    "Lima, Pérou",
    "Florence, Italie",
    "Singapour, Singapour",
    "Marrakech, Maroc",
    "Montréal, Canada",
    "Bangkok, Thaïlande",
    "San Francisco, États-Unis",
    "Prague, République tchèque",
    "Le Caire, Égypte",
    "Budapest, Hongrie",
    "Lisbonne, Portugal",
    "Rio de Janeiro, Brésil",
    "Vienne, Autriche",
    "Copenhague, Danemark",
    "Édimbourg, Royaume-Uni",
    "Séoul, Corée du Sud",
    "Jérusalem, Israël",
    "Zurich, Suisse",
    "La Havane, Cuba",
    "Vancouver, Canada",
    "Auckland, Nouvelle-Zélande",
    "Madrid, Espagne",
    "Hawaï, États-Unis",
    "Stockholm, Suède",
    "Cape Town, Afrique du Sud",
    "Le Caire, Égypte",
    "Reykjavik, Islande",
    "Édimbourg, Royaume-Uni"
]

# %%
output="output/"

from PIL import Image

num_imgs = 50
#"Keanu Reeves portrait photo of a asia old warrior chief, tribal panther make up, blue on red, side profile, looking away, serious eyes, 50mm portrait photography, hard rim lighting photography"
prompts = []
for i in range(num_imgs):
  #prompt="Keanu Reeves portrait photo of a " + asia_warrior_variations[i]  +", " + makeup_variations[i] + ", " +blue_on_red[i] +", Profile view, Look at the camera, " + serious_eyes_variations[i] +", 50mm portrait photography, hard rim lighting photography"
  prompt = endroits_populaires [i] +", Modern illustration, fantasy"
  prompts.append(prompt)

for i in range(num_imgs):
  print(prompts[i])
  prompt = [prompts[i]]
  images = pipe(prompt, height=512, width=512).images
  image=images[0]
  image
  image.save(f""+output+"/image"+str(i)+".png")
  all_images.extend(images)
# Out:
# Paris, France, Modern illustration, fantasy
#   0%|          | 0/50 [00:00<?, ?it/s]
# New York City, États-Unis, Modern illustration, fantasy
#   0%|          | 0/50 [00:00<?, ?it/s]
# Rome, Italie, Modern illustration, fantasy
#   0%|          | 0/50 [00:00<?, ?it/s]
# Barcelone, Espagne, Modern illustration, fantasy
#   0%|          | 0/50 [00:00<?, ?it/s]
# Tokyo, Japon, Modern illustration, fantasy
#   0%|          | 0/50 [00:00<?, ?it/s]
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 13>:16                                                                            │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py:115 in decorate_context       │
# │                                                                                                  │
# ...
